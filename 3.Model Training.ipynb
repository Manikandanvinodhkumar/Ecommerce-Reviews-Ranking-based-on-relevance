# %%
import pandas as pd
import numpy as np
from joblib import load, dump
from copy import deepcopy
from statistics import mean

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from collections import Counter

# %%
df = pd.read_csv('data/Features.csv')

# %%
df
# Out:
#                    product                                      answer_option  \
# 0                Accucheck                         Fast and accurate delivery
# 1                Accucheck  Expected a longer expire date. Your Product Li...
# 2                Accucheck                         I liked the prompt service
# 3                Accucheck                                       Good product
# 4                Accucheck                                       I not needed
# 5                Accucheck                          Not received the product.
# 6                Accucheck  The chip is not given that I actually was looking
# 7                Accucheck              Damage in your accu chek active strip
# 8                Accucheck                       The reading is very accurate
# 9                Accucheck  I PREFER A STRIP THAT DRAW BLOOD .INSTEAD OF A...
# 10               Accucheck                               it was good service.
# 11               Accucheck                                           Reliable
# 12               Accucheck                               It is a good product
# 13               Accucheck                                               Good
# 14               Accucheck                                       Not used yet
# 15               Accucheck            Good price with Comfortable expire date
# 16               Accucheck                                I like the accuracy
# 17               Accucheck                                      Easy ordering
# 18               Accucheck                                      Late delivery
# 19               Accucheck  It had only 7 months validity on delivery agai...
# 20               Accucheck                          Strips not Working at all
# 21               Accucheck                                    Latest mfg date
# 22               Accucheck  The delivery was fast and good Reason for low ...
# 23               Accucheck  Timely delivery competitive rates ease of orde...
# 24               Accucheck                                            On time
# 25               Accucheck  You have not given any discount on my order of...
# 26               Accucheck                                            dislike
# 27               Accucheck                         year validity Good packing
# 28               Accucheck                            Calibration takes time.
# 29               Accucheck                  Good quality with long shelf life
# 30               Accucheck               Dislike due to price too much higher
# 31               Accucheck                                       Nice product
# 32               Accucheck                                       Working fine
# 33               Accucheck                                            show E5
# 34               Accucheck                                    Wrongly ordered
# 35               Accucheck                                 Item received fast
# 36               Accucheck                                  Meets requirement
# 37               Accucheck                                    Timely delivery
# 38               Accucheck                                    Timely delivery
# 39               Accucheck                                       Good working
# 40               Accucheck    The packing and on time delivery of the product
# 41               Accucheck                                       Good product
# 42               Accucheck                                       Good service
# 43               Accucheck        The time/days took to deliver is really bad
# 44               Accucheck                                   EXCELLENT IN USE
# 45               Accucheck            Work is good but motivation chip missed
# 46               Accucheck                                    Timely delivery
# 47               Accucheck                                    Timely delivery
# 48               Accucheck                         Accurate Monitoring Device
# 49               Accucheck                                             Its ok
# 50               Accucheck                                   Customer service
# 51               Accucheck  It is good for testing the sugar liable in the...
# 52               Accucheck                   ALL IS WELL . NOTHING TO DISLIKE
# 53               Accucheck                                   time of delivery
# 54               Accucheck                                   I like very much
# 55               Accucheck                      Packing should be of 25 pics.
# 56               Accucheck                                        Nyc packing
# 57               Accucheck                                      It is Genuine
# 58               Accucheck                                    Good as assured
# 59               Accucheck           Only 40 strip inside,very bad experience
# 60               Accucheck             Delivery time.. required fast delivery
# 61               Accucheck                                   Original product
# 62               Accucheck                                            Dislike
# 63               Accucheck             Quick result for test and easy to use.
# 64               Accucheck                                        Easy to use
# 65               Accucheck             Dimly delivered and quality ie Good...
# 66               Accucheck                Well coordinate and on time service
# 67               Accucheck                                          I like it
# 68               Accucheck  Packaging was good Delivery was on time. Overa...
# 69               Accucheck  You dont send the thing we ordered online Even...
# 70               Accucheck                      Using for monitoring diabetes
# 71               Accucheck  The expire of the product is only of 6 onth wh...
# 72               Accucheck                 Excellent thing on excellent price
# 73               Accucheck                                  No discount given
# 74               Accucheck                                        Well packed
# 75               Accucheck  I like it because it is very cheap and having ...
# 76               Accucheck                                     On Not Service
# 77               Accucheck  Mention the manufacturing date and expire of O...
# 78               Accucheck                            Too much costly affair.
# 79               Accucheck                               I like past delivery
# 80               Accucheck                                    Correct rejalet
# 81               Accucheck  Your Courier partner is misleading and not del...
# 82               Accucheck             Instant Delivery and Reasonable price!
# 83               Accucheck                                            Nothing
# 84               Accucheck                                      Fast delivery
# 85               Accucheck   Some of the stripes inside the box is not proper
# 86               Accucheck                                       All was well
# 87               Accucheck                                             its ok
# 88               Accucheck    Your offered dismounted price and fast delivery
# 89               Accucheck  For accuracy of Blood sugar monitoring on dail...
# 90               Accucheck                         Price n delivery n quality
# 91               Accucheck  Perfect packing and delivery , but price wise ...
# 92               Accucheck  It is not working please return and refund my ...
# 93               Accucheck                                 Box is low quality
# 94               Accucheck  Rate on app are Rs.799 while print on box are ...
# 95               Accucheck                                Gave me insta strip
# 96               Accucheck                                  Liked the product
# 97               Accucheck                    Cost should be more competitive
# 98               Accucheck                  Excellent for blood sugar checkup
# 99               Accucheck                            Street nahin mila Mujhe
# 100              Accucheck  I order accucheck instant strip but got differ...
# 101              Accucheck                                          i like it
# 102              Accucheck                                  Excellent service
# 103              Accucheck      nice product. I am using it since last 10 yes
# 104              Accucheck                                               good
# 105              Accucheck                 I like the price and time delivery
# 106              Accucheck                                               Good
# 107              Accucheck                 I dislike it as i was over charged
# 108              Accucheck                                               Good
# 109              Accucheck  Like and reasonable price and correct time del...
# 110              Accucheck                                    Timely delivery
# 111              Accucheck                   Nice product and prompt delivery
# 112              Accucheck                                          Ok , good
# 113              Accucheck                         Price can still be refuced
# 114              Accucheck                                  Speed of delivery
# 115              Accucheck                 Quick dispatch and timely delivery
# 116              Accucheck                                      Late delivery
# 117              Accucheck                              Its like Good product
# 118              Accucheck  Suppliers are theaters They supply outdated me...
# 119              Accucheck                                 Its defected peice
# 120              Accucheck                          Description was not clear
# 121              Accucheck                                            I liked
# 122              Accucheck                                    Precise results
# 123              Accucheck  Everything was ok delivery,packing etc just ma...
# 124              Accucheck                                    Timely delivery
# 125              Accucheck                             Good strip. Keep it up
# 126              Accucheck                                       Good packing
# 127              Accucheck                                       Good service
# 128              Accucheck                                       Good product
# 129              Accucheck                                   Accurate reading
# 130              Accucheck                                          Very good
# 131              Accucheck                like , good for sugar check at home
# 132              Accucheck  cost of strips is very high seems you are taki...
# 133              Accucheck                  There was no chip in package.....
# 134              Accucheck                                   Reasonable rates
# 135              Accucheck                             It shows quick results
# 136              Accucheck                                       Nice packing
# 137              Accucheck                               It is medium quality
# 138              Accucheck                                      From delivery
# 139              Accucheck  Box nicely timely delivered Strips result is p...
# 140              Accucheck           Expire date is 12/2020,this is very less
# 141              Accucheck                      Good deal and genuine product
# 142              Accucheck                                      good services
# 143              Accucheck                         It gives immediate results
# 144              Accucheck                          Speedy Delivery and price
# 145              Accucheck  Everything right from placing order to deliver...
# 146              Accucheck                                    prompt delivery
# 147              Accucheck              Good product with expire date of 2021
# 148              Accucheck                               Expire date was 2021
# 149              Accucheck                       Has been using for long time
# 150              Accucheck  I purchased Occur Check Instant Machine and or...
# 151              Accucheck                              Pack was found opened
# 152              Accucheck                                      Price is high
# 153              Accucheck                                        No comments
# 154              Accucheck                                               Good
# 155              Accucheck                                           All Good
# 156              Accucheck                          I am using since many yr.
# 157              Accucheck                                           Good boy
# 158              Accucheck  All are good except only one - the price is to...
# 159              Accucheck  Late delivery and I am not able to redeem my w...
# 160              Accucheck                                   Timely delivered
# 161              Accucheck                                 Long delivery time
# 162              Accucheck                              Received as described
# 163              Accucheck         Worked perfectly No coming required either
# 164              Accucheck                                 New box only i got
# 165              Accucheck                                      Fast delivery
# 166              Accucheck  Strip very good but price is very high with ot...
# 167              Accucheck          I loved this product.Shelcal gives energy
# 168              Accucheck  It did not serve my purpose since my machine i...
# 169              Accucheck                                          Good deal
# 170              Accucheck                                       good service
# 171              Accucheck                                       Good results
# 172              Accucheck                                  Delivered on time
# 173              Accucheck              I was not delivered the right product
# 174              Accucheck                                  Liked the package
# 175              Accucheck                                      Fast delivery
# 176              Accucheck                                               Good
# 177              Accucheck                                            Packing
# 178              Accucheck                                      Fast delivery
# 179              Accucheck                                         It is good
# 180              Accucheck  Delivery was on time and there was reasonably ...
# 181              Accucheck            Early delivery with online payment mode
# 182              Accucheck                                               Good
# 183              Accucheck                                             all ok
# 184              Accucheck                       Delivery before sexual given
# 185              Accucheck  The product appears on the cart is different f...
# 186              Accucheck                       Due to exp date is very near
# 187              Accucheck  I have been using it for some time and was ful...
# 188              Accucheck     The strips showing E 1 error and not recording
# 189              Accucheck                          Need improvement delivery
# 190              Accucheck                              Reliable and economic
# 191              Accucheck                                    timely delivery
# 192              Accucheck                                       Good service
# 193              Accucheck                                    Nothing special
# 194              Accucheck                                Nothing all is good
# 195              Accucheck                                    Prompt Delivery
# 196              Accucheck            Arrived fast and exact material ordered
# 197              Accucheck                                Willingness to help
# 198              Accucheck                                             I like
# 199              Accucheck                        Nice price with long expire
# 200              Accucheck                                               Like
# 201              Accucheck           Nothing specific about the strip though.
# 202              Accucheck                                 Please process fst
# 203              Accucheck  Fast and Reliable Product. Ordered it for my f...
# 204              Accucheck                     Timely supply,and good product
# 205              Accucheck                            Cost is not competitive
# 206              Accucheck  at first the delivered product was wrong one w...
# 207              Accucheck                                   Product dispatch
# 208              Accucheck  Still I have not get this product and this one...
# 209              Accucheck                             Good. Delivery on time
# 210              Accucheck                                 Price and discount
# 211              Accucheck                 Very effective and accurate strips
# 212              Accucheck                                       Best product
# 213              Accucheck                                   Reduction in MRP
# 214              Accucheck  Correct measurement cheaper in comparison buyi...
# 215              Accucheck                                     Reliable price
# 216              Accucheck                                 Nothing to dislike
# 217              Accucheck                     Not like the billing procedure
# 218              Accucheck  I have been using it for my grandfather since ...
# 219              Accucheck                     Timely delivery of the product
# 220              Accucheck  the worst product from the company we couldn f...
# 221              Accucheck  Product and price is good but delivery service...
# 222              Accucheck           Excellent for regular n easy gluco meter
# 223              Accucheck                                    courier service
# 224              Accucheck                             Price and authenticity
# 225              Accucheck                                   I want to return
# 226              Accucheck  Dislike that there is no provision to change e...
# 227              Accucheck                                   Yeah that is ok.
# 228              Accucheck  One of the packet containing 50 strips was fou...
# 229              Accucheck                    I think its genuine and perfect
# 230              Accucheck                   Easy to use and accurate results
# 231              Accucheck         Occur check strip box dont have code strip
# 232              Accucheck                       Prompt delivery,good rebates
# 233              Accucheck                                   Delivery is good
# 234              Accucheck                                           Mud rate
# 235              Accucheck  compared with the diagnostic lab results on th...
# 236              Accucheck             Wrong item sent and no remedy for that
# 237              Accucheck  Try to mention the expire date and mfg date in...
# 238              Accucheck                                        Not working
# 239              Accucheck  From response and delivery Maximum discount re...
# 240              Accucheck                                               good
# 241              Accucheck  The test strip 50 box sent along with machine ...
# 242              Accucheck                                      Good delivery
# 243              Accucheck                                      Late delivery
# 244              Accucheck                                          Very good
# 245              Accucheck                             its price and delivery
# 246              Accucheck                 Faster delivery at reasonable cost
# 247              Accucheck                                               Like
# 248              Accucheck                                 Very fast delivery
# 249              Accucheck                                      Fast delivery
# 250              Accucheck                             Very good.good results
# 251              Accucheck  On same code-chip operating original ....fast ...
# 252              Accucheck  Expire Date was good enough to help me in usin...
# 253              Accucheck                                 recent expire date
# 254              Accucheck                                 Product was damage
# 255              Accucheck                                    OK.VERY COSTLY.
# 256              Accucheck                                          Excellent
# 257              Accucheck           for prompt delivery and accurate product
# 258              Accucheck                         I think these are the best
# 259              Accucheck                          Delivery time is too late
# 260              Accucheck  In Occur Chen active test strip box , chip was...
# 261              Accucheck                                          Packaging
# 262              Accucheck  Price is very high Would be a blessing to seni...
# 263              Accucheck                              Very good every thing
# 264              Accucheck       Out if 5 strips one strip was showing error.
# 265              Accucheck                                               Good
# 266              Accucheck  Delivery was in time and product found well en...
# 267              Accucheck                             Expiration date is max
# 268              Accucheck         its doing its work for which its purchased
# 269              Accucheck                                               Good
# 270              Accucheck     very easily to get medicines which are genuine
# 271              Accucheck                   Prompt follow and quick disposal
# 272              Accucheck  There was no information regarding expire date...
# 273              Accucheck                                               Nice
# 274              Accucheck  Expired stripes written 2020 but expired in Ju...
# 275              Accucheck                       Dependable and easy to use .
# 276              Accucheck  I feel product is not original getting very lo...
# 277              Accucheck                                       Cost is high
# 278              Accucheck                                          Very good
# 279              Accucheck                                YOUR PROMPT SERVICE
# 280              Accucheck                                  Very good service
# 281              Accucheck                                           Delivery
# 282              Accucheck  Delivered on time, expecting next day deliver ...
# 283              Accucheck                               Accurate measurement
# 284              Accucheck                                          Very good
# 285              Accucheck                                       easy to use.
# 286              Accucheck              Easy to use and result in seconds....
# 287              Accucheck  Smart insert missing i complained on app but n...
# 288              Accucheck                           Purchase with best offer
# 289              Accucheck                                      Same code 333
# 290              Accucheck                   Late delivery division of orders
# 291              Accucheck                                      No complaints
# 292              Accucheck                      On time delivery and discount
# 293              Accucheck                                         Easy house
# 294              Accucheck                    Discount should have been given
# 295              Accucheck                                    Price & Service
# 296              Accucheck                                      Good discount
# 297              Accucheck  Prompt delivery with reasonable price. Discoun...
# 298              Accucheck  Like Good product in good packing at reasonabl...
# 299              Accucheck  Device is prompt.Staff who speaks on phone is ...
# 300              Accucheck  Everything went well From placing order , to r...
# 301              Accucheck                                               nice
# 302              Accucheck  Very poor delivery system took more than the e...
# 303              Accucheck                         dispatch on committed date
# 304              Accucheck                There is no discount on the product
# 305              Accucheck  on time delivery and product is as described s...
# 306              Accucheck  I have got this product from Paytm,as I find e...
# 307              Accucheck                         Good as per my expectation
# 308              Accucheck                                 Effective its good
# 309              Accucheck                                  Good but not good
# 310              Accucheck                                  All is very first
# 311              Accucheck  The product was delivered after days and too o...
# 312              Accucheck               Strips expire date is long that good
# 313              Accucheck       Low price. And fast gome delivery i like it.
# 314              Accucheck             Could you please improve delivery time
# 315              Accucheck  Whenever i am putting d strip in d machine its...
# 316              Accucheck         It ws the wrong product ordered by mistake
# 317              Accucheck  Packing and delivery is good Product is excellent
# 318              Accucheck                               nice as per required
# 319              Accucheck                  Please check my previous comments
# 320              Accucheck                           DELAYED IN DELIVERY TIME
# 321              Accucheck           The strips very accurately takes reading
# 322              Accucheck                i returned it as i needed Performa.
# 323              Accucheck                   Dislike is cost... Rest all good
# 324              Accucheck                                   its good to use.
# 325              Accucheck               Not satisfied with quality of strips
# 326              Accucheck              Best service & product have no issues
# 327              Accucheck                            The price is unfordable
# 328              Accucheck         Good in quality , produces aqurate result.
# 329              Accucheck                       Timely delivery good packing
# 330              Accucheck                           It was in time delivered
# 331              Accucheck                Great discount and on time delivery
# 332              Accucheck         Show E-5 after one month of opening packet
# 333              Accucheck  No SLA, pathetic customer support support was ...
# 334              Accucheck  Time take for delivery is total unacceptable Y...
# 335              Accucheck                  Packing is good delivered on time
# 336              Accucheck               Easy to use and give accurate result
# 337              Accucheck                                     A nice product
# 338              Accucheck     Strip is easy to use and give accurate results
# 339              Accucheck                                 Very bad condition
# 340              Accucheck  Dislike as it showed higher reading than original
# 341              Accucheck                             It is working as usual
# 342              Accucheck  Using since last 10years.Best for sugar levels...
# 343              Accucheck  Have been using it for a while and am happy wi...
# 344              Accucheck  Packing was horrible It was good that the stri...
# 345              Accucheck                      Quick delivery and good stuff
# 346              Accucheck  Nice product. Reliable I'm using approx 120 st...
# 347              Accucheck                             Good Occur check strip
# 348              Accucheck  Your packing was very bad and it was torn some...
# 349              Accucheck  Can not see expire before order all other is good
# 350              Accucheck                             Ease of doing business
# 351              Accucheck                       Product is good as described
# 352              Accucheck              Very Nice product and prompt delivery
# 353              Accucheck                        INTERNAL PACKING IS DAMAGED
# 354              Accucheck     It is not supported with the machine I ordered
# 355              Accucheck     It get deliver on time and I get good discount
# 356              Accucheck         packing is good and date of expire is more
# 357              Accucheck  its some Chinese vendor product not the actual...
# 358              Accucheck  Everything is right there but please try to cu...
# 359              Accucheck  Does not fit into my new Accu-Chek glucometer ...
# 360              Accucheck            I liked the simplifies ordering process
# 361              Accucheck                 My favorite daily needs as trusted
# 362              Accucheck                    Fast delivery with good packing
# 363              Accucheck                        Discount and quick response
# 364              Accucheck                            Does not fit my machine
# 365              Accucheck  Received 10 strips and 2 packets of lancets in...
# 366              Accucheck                              Fast service was good
# 367              Accucheck            These strips were as per my requirement
# 368              Accucheck  Behavior of delivery boy is very bad Delivery ...
# 369              Accucheck                             As usual it is genuine
# 370              Accucheck                have been using the product is fine
# 371              Accucheck                                The product is good
# 372              Accucheck                      Good discount & fast delivery
# 373              Accucheck  The supply is as per requirement and satisfaction
# 374              Accucheck  Previously the micro chip used to be of red co...
# 375              Accucheck                          Good to track sugar level
# 376              Accucheck     The Accu-Chek active strips are quite reliable
# 377              Accucheck                                      Price to high
# 378              Accucheck                 Some of the strips did not respond
# 379              Accucheck                  Good packing and on time delivery
# 380              Accucheck                        The strips are quite useful
# 381              Accucheck                 I have using for long No complain.
# 382              Accucheck               Wanted instant but sent active strip
# 383              Accucheck  no description mentioned in what machine it ca...
# 384              Accucheck                                     its gud to use
# 385              Accucheck                          Yes, I like this product.
# 386              Accucheck  I like that Accu-Check Active Strip box bc tha...
# 387              Accucheck                            Price expected RS 650/-
# 388              Accucheck        its value for money and cheaper than market
# 389              Accucheck                      It is easy to see blood sugar
# 390              Accucheck  addition of delivery charges on the purchase m...
# 391              Accucheck                        Overall experience was good
# 392              Accucheck    I like the app because it contains all medicine
# 393              Accucheck                                Nothing to dislike.
# 394              Accucheck  Product ordered wrong and not replace first ti...
# 395            Becadexamin  Selenium is missing and vitamin A is more than...
# 396            Becadexamin                          Good for daily supplement
# 397            Becadexamin  Becadexamin is a poorhouse of vitamin and it i...
# 398            Becadexamin            Chaljata hai ek marina sasta bhi hair 😂
# 399            Becadexamin                          One pensive yet effective
# 400            Becadexamin  Not at all recommended full of synthetic color...
# 401            Becadexamin         How can one rate medicines qualitatively??
# 402            Becadexamin  Bottles received in good condition. Product st...
# 403            Becadexamin      fast delivery neat packing and price discount
# 404            Becadexamin                      all ok. using since 30+ years
# 405            Becadexamin       Nothing to dislike. Its a good multi vitamin
# 406            Becadexamin  The packing and of course the delivery was ver...
# 407            Becadexamin                       No longer user starting soon
# 408            Becadexamin                      This is great muti vitamins..
# 409            Becadexamin                It works but have to give some time
# 410            Becadexamin                            Value for money vitamin
# 411            Becadexamin  Everything was perfect including product and d...
# 412            Becadexamin  Fast delivery,best quality medicine and great ...
# 413            Becadexamin              Should give more discount on purchase
# 414            Becadexamin  My father is taking the tablet for the last 30...
# 415            Becadexamin                           Cuorer facility not good
# 416            Becadexamin                              Delivery was too late
# 417            Becadexamin  Best multivitamin in this range as compared to...
# 418            Becadexamin                         great price, fast delivery
# 419            Becadexamin                                Good and beneficial
# 420            Becadexamin      Has always stood the test of time for quality
# 421            Becadexamin                  its much effective and unfordable
# 422            Becadexamin    Very nice medicine for vitamin s and supplement
# 423            Becadexamin                             No prescription needed
# 424            Becadexamin  All range of vitamin present, cost effective a...
# 425            Becadexamin  Very good small package of all vitamin and min...
# 426            Becadexamin  All in one Packing should be in plastic bottle...
# 427            Becadexamin            excellent product and customer service.
# 428            Becadexamin                    It is very useful and effective
# 429            Becadexamin         Quality is good....can feel the difference
# 430            Becadexamin  i am worried to take i took 1 and was having d...
# 431            Becadexamin  Good and economical multi vitamin mineral capsule
# 432            Becadexamin                        Quality at economical price
# 433            Becadexamin                          I have no result for that
# 434            Becadexamin                             Low price good product
# 435            Becadexamin                              Like - They are cheap
# 436            Becadexamin       This is an old product, not much improvement
# 437            Becadexamin             Good quality easily available product.
# 438            Becadexamin                         Timely delivery n discount
# 439            Becadexamin                        Good multi vitamin tablet..
# 440            Becadexamin                                Product is soo good
# 441            Becadexamin                             Effective at low price
# 442            Becadexamin  Its prescribed to from one of the best Dr, I w...
# 443            Becadexamin                            It gives extra strength
# 444            Becadexamin                              It was helpful for me
# 445            Becadexamin                         Not very useful as Vitamin
# 446            Becadexamin                           Delay in courier Service
# 447            Becadexamin                    As good as it is supposed to be
# 448            Becadexamin  It was suggested by doctors and my son like it...
# 449            Becadexamin      It gets sticky even when kept in refrigerator
# 450            Becadexamin                                I like it very much
# 451            Becadexamin  Since it is a multivitamin capsule and I am tr...
# 452            Becadexamin                                  very good product
# 453            Becadexamin                                 It is good product
# 454            Becadexamin                Very useful . Nd powerful capsule .
# 455            Becadexamin                       Price is lower on other site
# 456            Becadexamin  This is not expensive compare with any other m...
# 457            Becadexamin                        Bacadexamin is nice tablets
# 458            Becadexamin                      Good supplement... Unfordable
# 459            Becadexamin              Good vitamin source at cheapest price
# 460            Becadexamin                         The product is really good
# 461            Becadexamin                              Good and shows result
# 462            Becadexamin  Good and reliable source of vitamin but quanti...
# 463            Becadexamin  I bought it because not available in my city,,...
# 464            Becadexamin            product quality is ok as per the price.
# 465            Becadexamin  its very cheap but very good energy for our da...
# 466            Becadexamin                        personalized health product
# 467            Becadexamin  Why do you ask this Are you doubtful about its...
# 468            Becadexamin            Best and cheapest multivitamin capsules
# 469            Becadexamin  Liked it. The bottle is of glass i thougt it t...
# 470            Becadexamin  Very effective but I dont like the smell of ca...
# 471            Becadexamin           I am using the product and its very good
# 472            Becadexamin                                Sentatic no so good
# 473            Becadexamin                          Little costly then market
# 474            Becadexamin       I am consuming this product for a long time.
# 475                  Evion  packing and delivery on time...shipping charge...
# 476                  Evion  Its not about the medicine, its really good it...
# 477                  Evion                                 i like the service
# 478                  Evion                             Packing not sufficient
# 479                  Evion                                    No side effects
# 480                  Evion                         Need long time to c effect
# 481                  Evion                               Must buy for any use
# 482                  Evion             Super platform to get genuine medicine
# 483                  Evion                      its very useful and very good
# 484                  Evion  Union 400mg is Vitamin E supplement to be take...
# 485                  Evion      Using it regularly as a vitamin e requirement
# 486                  Evion  This drug is effective in peripheral nurologic...
# 487                  Evion  cost is less than your service charge and same...
# 488                  Evion          Prescription not accepted for whole order
# 489                  Evion  this medicine has been prescribed by doctor an...
# 490                  Evion                                    Liked very much
# 491                  Evion                   good packing and prompt service.
# 492                  Evion               Price more then MRP written on strip
# 493                  Evion  Medicine ok Service is hard to Without service...
# 494                  Evion  I take It E for my skin hair n nails since a l...
# 495                  Evion                           delivery was not on time
# 496                  Evion                           Discount on this product
# 497                  Evion                         Wonderful caps for my hair
# 498                  Evion                            Cheap and great quality
# 499                  Evion  just fine not sure if this is a duplicate product
# 500                  Evion                       It is best for hair and skin
# 501                  Evion  Good tablet for PMS relief but paraben is a ca...
# 502                  Evion                       Very good for liver and skin
# 503                  Evion              Packing... Early Delivery... Discount
# 504                  Evion                          I am agree pl send on cod
# 505                  Evion  Panelling of partial order by the merchant aft...
# 506                  Evion  Using it for many years Gives a comfortable fe...
# 507                  Evion                       Sorry, this is my last order
# 508                  Evion                Well it is meant for what its meant
# 509                  Evion  we dont know as per doctor prescription we are...
# 510                  Evion  Its good that evion has 2 variant 400mg and 600mg
# 511                  Evion               another experiment , never completed
# 512                  Evion           Good and really useful for skin and hair
# 513                  Evion                All the tablets have very bad smell
# 514                  Evion          Because of your poor service for delivery
# 515                  Evion               IT WAS GOOD TO BUY MEDICINE FROM YOU
# 516                  Evion                         Vitamin e need a body face
# 517                  Evion  Delivery is fast but some medicines have disco...
# 518                  Evion                           I like the 600gms better
# 519                  Evion                             It was normal delivery
# 520                  Evion                     Quick delivery and the packing
# 521                  Evion   Its good it E capsule I use it with my hair oil.
# 522                  Evion                              Quickness of delivery
# 523                  Evion               Good for hair ... regularly using...
# 524                  Evion                                 its very effective
# 525                  Evion                                        Good tabiat
# 526                  Evion                                Good for vitamin e.
# 527                  Evion                                  Good for dry skin
# 528                  Evion                       Very good for skin and hairs
# 529                  Evion                                      pL keep it up
# 530                  Evion                   Vitamin e used for hair and skin
# 531                  Evion                 Thanks,It helps my hair grow again
# 532                  Evion       Hasn't helped much with my hair fall problem
# 533                  Evion  I like your fast delivery but I dislikes that ...
# 534                  Evion      Capsule is available in less price in market.
# 535                  Evion                    Excellent capsule for Vitamin E
# 536                  Evion              Product was delivered very late to me
# 537                  Evion                      it is not available regularly
# 538                  Evion             So nice best result with best discount
# 539                  Evion                  the capsule is too mess to handle
# 540                  Evion                                   Offers r not gud
# 541                  Evion                           I LIKE COST AND DELIVERY
# 542                  Evion                             It does what it claims
# 543                  Evion   It needed more articles or research on Vitamin E
# 544                  Evion  In one strip 2 tablets were not there it was e...
# 545                  Evion                                  Don't want to say
# 546                  Evion                          Very fast delivery thanks
# 547                  Evion                        my need fulfil in shorttime
# 548                  Evion                    Like... Fast courier service...
# 549                  Evion                   Nice packing and genuine product
# 550                  Evion                         Easy to use with low price
# 551                  Evion            It has whitening qualities for the skin
# 552                  Evion                  data compromised no purchase done
# 553                  Evion          Prescribed to me for treating fatty liver
# 554                  Evion  Nothing to dislike. The products arrived next ...
# 555                  Evion                           delivery was not on time
# 556                  Evion            Delivery service and better expire date
# 557                  Evion                        Amazing result in evion 400
# 558                  Evion  Delivery of medicines was expected on same day...
# 559                  Evion                                It is good for skin
# 560                  Evion                    Good for hair and face and body
# 561                  Evion                             its good for vitamin E
# 562                  Evion                               Cheapest & Effective
# 563                  Evion       BEST SERVICE BY VENDOR AND VERY FAST SERVICE
# 564                  Evion     Delivery could be little faster otherwise okay
# 565                  Evion                        Unable to confirm the order
# 566                  Evion                  It was delivered in a secured way
# 567                  Evion                                i like this product
# 568                  Evion                    Very useful anf value for money
# 569                  Evion  Capsules are hard coat compare to the normal s...
# 570                  Evion  Fast shipping with billing print out with free...
# 571                  Evion                    Delivery and price i like in it
# 572                  Evion                             Not so good not so bad
# 573                  Evion                      Like the delivery and packing
# 574                  Evion  its a good and effective capsule especially fo...
# 575                  Evion                           good Source of vitamin E
# 576                  Evion  It was good Bt i find it cheaper in local medi...
# 577                  Evion             I take it as a It E supplement Hats it
# 578                  Evion                                   Nice as expected
# 579                  Evion                        Good - to be taken with fat
# 580                  Evion                          Great for skin and nerves
# 581                  Evion                               Later on after using
# 582                  Evion                  Delivery schedule was not kept up
# 583                  Evion                                Perfect it e tablet
# 584                  Evion  Union 400 is an unfordable medicine for noctur...
# 585                  Evion  It'sa vitamin E supplement It requires nothing...
# 586                  Evion  Delay in Delivery and absence of updated commu...
# 587                  Evion                      It fulfills need of vitamin e
# 588                  Evion                           It is effective product.
# 589                  Evion                               This is good capsule
# 590                  Evion                I dislike the less rate of discount
# ...
# 589   0.4404
# 590  -0.3818
# 591   0.6486
# 592   0.7506
# 593   0.5267
# 594   0.3612
# 595   0.4215
# 596   0.4927
# 597   0.0000
# 598   0.0000
# 599   0.7506
# 600  -0.2732
# 601   0.8020
# 602   0.5994
# 603   0.4404
# 604   0.5859
# 605   0.4404
# 606   0.0000
# 607   0.6249
# 608   0.5719
# 609   0.4404
# 610   0.0000
# 611   0.0000
# 612   0.4404
# 613   0.0000
# 614   0.4404
# 615   0.3612
# 616  -0.3724
# 617   0.3612
# 618   0.3612
# 619   0.5023
# 620   0.4215
# 621   0.0000
# 622   0.0000
# 623   0.0000
# 624   0.3612
# 625   0.5859
# 626   0.6369
# 627   0.4404
# 628   0.4404
# 629  -0.5106
# 630   0.0000
# 631   0.7184
# 632   0.4404
# 633   0.3612
# 634   0.4927
# 635   0.0000
# 636   0.8316
# 637   0.4404
# 638   0.4404
# 639   0.6486
# 640   0.0000
# 641   0.0000
# 642   0.4404
# 643   0.4404
# 644   0.0000
# 645   0.0000
# 646  -0.4019
# 647   0.4927
# 648   0.0000
# 649   0.0000
# 650   0.0000
# 651   0.6249
# 652  -0.6230
# 653   0.0000
# 654   0.1082
# 655   0.0000
# 656   0.0000
# 657   0.4754
# 658  -0.5106
# 659   0.0000
# 660   0.0000
# 661   0.0000
# 662   0.0000
# 663   0.6249
# 664  -0.0772
# 665   0.4404
# 666   0.4404
# 667   0.6249
# 668   0.0000
# 669   0.0000
# 670   0.5859
# 671   0.0000
# 672   0.4404
# 673   0.5719
# 674   0.4404
# 675   0.4215
# 676  -0.2960
# 677  -0.4588
# 678  -0.3818
# 679   0.4215
# 680   0.0000
# 681  -0.5574
# 682   0.2382
# 683   0.4404
# 684   0.0000
# 685   0.7425
# 686   0.3612
# 687   0.4404
# 688   0.6369
# 689   0.0000
# 690   0.4404
# 691   0.4754
# 692   0.2960
# 693  -0.2732
# 694   0.0000
# 695   0.7418
# 696   0.4404
# 697   0.4404
# 698   0.6643
# 699   0.4404
# 700   0.3182
# 701   0.4404
# 702   0.3595
# 703   0.4404
# 704   0.4215
# 705   0.0000
# 706   0.5719
# 707   0.6597
# 708   0.3182
# 709   0.4404
# 710   0.4404
# 711   0.5719
# 712  -0.0286
# 713   0.0000
# 714  -0.5106
# 715   0.0258
# 716   0.6369
# 717   0.0000
# 718   0.6249
# 719   0.4404
# 720   0.4215
# 721   0.3612
# 722   0.9022
# 723  -0.6597
# 724   0.0000
# 725   0.4404
# 726   0.0000
# 727  -0.3818
# 728   0.6124
# 729   0.0000
# 730   0.0000
# 731   0.3384
# 732   0.0000
# 733  -0.3412
# 734   0.5859
# 735   0.0000
# 736   0.5719
# 737   0.4767
# 738   0.6249
# 739   0.3612
# 740   0.0000
# 741   0.2960
# 742   0.8690
# 743   0.0000
# 744   0.4404
# 745   0.6369
# 746   0.6705
# 747   0.7650
# 748   0.0000
# 749   0.5719
# 750   0.5256
# 751   0.4404
# 752   0.4404
# 753   0.4019
# 754  -0.2960
# 755   0.5106
# 756   0.0000
# 757   0.0000
# 758   0.0000
# 759  -0.5096
# 760  -0.0772
# 761   0.4404
# 762   0.0000
# 763   0.0000
# 764   0.8020
# 765   0.0000
# 766   0.4404
# 767  -0.2755
# 768   0.7184
# 769   0.4404
# 770  -0.2960
# 771   0.4927
# 772   0.4767
# 773   0.0000
# 774   0.6249
# 775   0.5719
# 776   0.6369
# 777   0.4404
# 778   0.0516
# 779   0.4404
# 780   0.6369
# 781   0.4404
# 782   0.4404
# 783  -0.3818
# 784   0.4404
# 785   0.3612
# 786   0.4404
# 787   0.6908
# 788   0.6249
# 789   0.3818
# 790   0.4404
# 791   0.4939
# 792   0.4215
# 793   0.0000
# 794   0.1280
# 795   0.0000
# 796   0.2732
# 797   0.4927
# 798   0.5719
# 799   0.6369
# 800   0.0258
# 801   0.0000
# 802   0.0000
# 803   0.0000
# 804   0.6249
# 805   0.4215
# 806   0.4404
# 807   0.5719
# 808   0.0516
# 809   0.0000
# 810   0.4927
# 811  -0.2411
# 812   0.0000
# 813   0.4404
# 814   0.4404
# 815   0.0000
# 816   0.3400
# 817   0.5267
# 818   0.0000
# 819   0.4404
# 820   0.6597
# 821   0.4927
# 822   0.4215
# 823   0.0000
# 824   0.6249
# 825   0.4404
# 826   0.0000
# 827   0.0258
# 828   0.0000
# 829  -0.1779
# 830   0.4404
# 831   0.4767
# 832   0.4215
# 833  -0.2960
# 834   0.5696
# 835   0.6249
# 836   0.7096
# 837  -0.0286
# 838   0.4927
# 839   0.0000
# 840   0.0000
# 841   0.4404
# 842   0.0000
# 843  -0.2732
# 844   0.6486
# 845   0.5696
# 846   0.3612
# 847   0.4404
# 848  -0.3013
# 849   0.4404
# 850  -0.1779
# 851   0.6369
# 852   0.4404
# 853   0.0000
# 854   0.3818
# 855   0.3182
# 856   0.0000
# 857   0.2382
# 858   0.6249
# 859   0.2960
# 860  -0.0772
# 861   0.4404
# 862   0.6249
# 863   0.6597
# 864   0.1280
# 865   0.0000
# 866   0.5719
# 867   0.4215
# 868  -0.5106
# 869   0.4215
# 870   0.4404
# 871   0.0000
# 872   0.7096
# 873   0.0000
# 874   0.0000
# 875   0.8690
# 876   0.2023
# 877   0.3612
# 878  -0.4767
# 879   0.6249
# 880   0.4215
# 881   0.0000
# 882   0.0000
# 883   0.4404
# 884   0.0000
# 885   0.0000
# 886   0.0000
# 887   0.4404
# 888   0.4404
# 889   0.4404
# 890   0.3089
# 891   0.7506
# 892   0.0000
# 893   0.4927
# 894   0.4939
# 895   0.4404
# 896  -0.0772
# 897   0.3612
# 898   0.8316
# 899   0.4404
# 900  -0.0516
# 901   0.4404
# 902   0.0000
# 903   0.0000
# 904   0.6808
# 905  -0.2716
# 906   0.4404
# 907   0.3919
# 908   0.8020
# 909   0.0000
# 910  -0.5859
# 911   0.5106
# 912   0.4404
# 913   0.6369
# 914   0.0000
# 915   0.6249
# 916   0.4404
# 917   0.4404
# 918   0.0000
# 919   0.2732
# 920   0.5842
# 921   0.6249
# 922   0.0000
# 923   0.6590
# 924  -0.4019
# 925  -0.3818
# 926  -0.3818
# 927   0.0000
# 928   0.4767
# 929   0.0000
# 930  -0.1779
# 931   0.0000
# 932  -0.2960
# 933   0.0000
# 934   0.0000
# 935   0.0000
# 936   0.0000
# 937   0.3595
# 938   0.0000
# 939   0.5733
# 940   0.7579
# 941   0.2382
# 942   0.7418
# 943  -0.3252
# 944  -0.3013
# 945   0.6369
# 946   0.4404
# 947   0.2960
# 948   0.4404
# 949   0.0000
# 950   0.4404
# 951   0.0000
# 952   0.0000
# 953   0.6249
# 954   0.2960
# 955  -0.4019
# 956   0.0000
# 957   0.4404
# 958   0.4767
# 959   0.8969
# 960   0.0000
# 961   0.0000
# 962   0.2382
# 963   0.2960
# 964   0.0000
# 965   0.6249
# 966   0.7964
# 967   0.4404
# 968   0.0000
# 969   0.4215
# 970   0.4404
# 971   0.9022
# 972   0.3612
# 973  -0.3818
# 974   0.6369
# 975   0.0000
# 976   0.4404
# 977   0.3089
# 978   0.4404
# 979   0.4215
# 980   0.0000
# 981   0.5256
# 982   0.0000
# 983   0.0000
# 984   0.0000
# 985   0.0000
# 986   0.4404
# 987   0.4927
# 988   0.2732
# 989   0.0000
# 990   0.5719
# 991   0.0000
# 992   0.0000
# 993   0.0000
# 994   0.1531
# 995   0.6249
# 996   0.4215
# 997   0.0000
# 998   0.0000
# 999   0.4404
# 1000  0.4215
# 1001  0.4215
# 1002  0.7147
# 1003  0.1779
# 1004  0.4404
# 1005  0.6936
# 1006  0.4404
# 1007  0.0000
# 1008  0.4404
# 1009  0.4404
# 1010  0.4939
# 1011 -0.0258
# 1012  0.4404
# 1013 -0.2960
# 1014  0.6369
# 1015  0.5106
# 1016  0.0000
# 1017  0.7717
# 1018  0.0000
# 1019 -0.1994
# 1020 -0.4019
# 1021  0.0000
# 1022  0.2006
# 1023 -0.5849
# 1024 -0.3412
# 1637  0.2475
# 1638  0.1531
# 1639  0.7096
# 1640  0.0772
# 1641  0.2382
# 1642  0.7783
# 1643  0.5927
# 1644  0.7574
# 1645  0.1779
# 1646  0.4927
# 1647  0.0000
# 1648  0.0000
# 1649  0.9022
# 1650 -0.3724
# 1651  0.5709
# 1652  0.0000
# 1653 -0.4032
# 1654 -0.1263

# %% [markdown]
# ### Ranking is a canonical problem for humans. It is easy to classify whether a review is useful (informative) or not. However, ranking reviews on the basis of usefulness, is a complex task. Our ranking methodology is based on this simple education.
#
# #### Pairwise ranking approach is applied to rank reviews in the semi-supervised learning method. The pairwise ranking approach looks at a pair of documents at a time in a loss function and predicts a relative ordering. The objective is not to determine the relevance score but to find which document is more relevant than others. This relevance is developed to judge the preference of one review over another.
# #### In the semi-supervised learning method, mapping is constructed between input and output. This input-output pair in the training model is used to learn the system.
# #### Review Segregation: We segregated two sets of reviews on which we train our model.
# + Set 0 represents reviews with label 0, i.e., ones that are not informative. These include reviews based on delivery, customer support, packaging, etc. These reviews do not describe the product.
# + Set 1 represents reviews with label 1, i.e., reviews that are informative and are better than all reviews of Set 0;
# #### How we segregated and determined labels for reviews:
# ### `Our entire review ranking system is based on the idea that it is easier for humans to binary classify reviews which we call Set 0 and Set 1.`
#
# For each product 'Accucheck', 'Becadexamin', 'Evion', 'Neurobion','SevenseascodLiverOil', 'Shelcal', 'Supradyn','shampoo', we asked 10 different people to label reviews as a 1 (informative review) and 0 ( not informative review). Different participants were asked to label so that there is no bias and the model learns to its best.

# %%
data_split = pd.crosstab(df['product'],df['label'])
data_split
# Out:
# label                   0    1
# product
# Accucheck             310   85
# Becadexamin            53   27
# Evion                  89   33
# Neurobion             280  136
# SevenseascodLiverOil   59   22
# Shelcal               259  124
# Supradyn               50   23
# shampoo                56   49

# %%
 data_split[data_split.index == 'Accucheck'][1]
# Out:
# product
# Accucheck    85
# Name: 1, dtype: int64

# %% [markdown]
# ## Building the training set:
# #### We pairwise compared each review of set1 with all reviews of set0 and vice-versa
# + (Rx, Ry,1) where x∈Set1 and y∈Set0 → Rx is better than Ry
# + (Ry, Rx, 0) where x∈Set1 and y∈Set0 → Ry is worst than Rx
# <br>
#
# #### This now becomes a classification problem.
#
# <hr>
#
# ![PairwiseRanking](Photos/PairwiseRanking.png)

# %%
def building_training_data(df):
    A = df[df['label']==1]
    A.loc[df['label']==1,'join'] = 'j'
    B = df[df['label']==0]
    B.loc[df['label']==0,'join'] = 'j'
    trainset1 = pd.merge(A,B,how='outer',on='join')
    trainset2 = pd.merge(B,A,how='outer',on ='join')

    trainset = pd.merge(trainset1,trainset2,how='outer')
    return trainset,trainset1,trainset2,A,B

# %%
product_list = df['product'].unique()
data_stack = []
for product in product_list:
    temp = deepcopy(df[df['product']==product].iloc[:,2:])
    build_data,t1,t2,A,B = building_training_data(temp)
    print(product, len(temp), len(build_data))
    build_data.drop(columns = ['join','label_y'],inplace=True)
    data = build_data.iloc[:,1:]
    data['target'] = build_data.iloc[:,0]
    data_stack.append(data)
# Out:
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# Accucheck 395 52700
# Becadexamin 80 2862
# Evion 122 5874
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# Neurobion 416 76160
# SevenseascodLiverOil 81 2596
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# Shelcal 383 64232
# Supradyn 73 2300
# shampoo 105 5488
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\manik\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
#build_data

#pd.set_option = (1000,1000)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#pd.set_option('display.max_rows', 500)
#pd.set_option('display.max_columns', 500)
#pd.set_option('display.width', 1000)
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 200

# %%
t2.head()
# Out:
#    label_x  review_len_x      Rn_x  Rp_x  Rs_x      Rc_x  Rd_x   Rsc_x join  \
# 0        0             7  0.540337   1.0   0.3  0.016706   0.0  0.7717    j
# 1        0             7  0.540337   1.0   0.3  0.016706   0.0  0.7717    j
# 2        0             7  0.540337   1.0   0.3  0.016706   0.0  0.7717    j
# 3        0             7  0.540337   1.0   0.3  0.016706   0.0  0.7717    j
# 4        0             7  0.540337   1.0   0.3  0.016706   0.0  0.7717    j
#
#    label_y  review_len_y      Rn_y  Rp_y  Rs_y      Rc_y  Rd_y   Rsc_y
# 0        1            12  0.681312  -0.1   0.4  0.026253   0.0  0.1891
# 1        1             8  0.407447   0.2   0.2  0.019093   0.0  0.6865
# 2        1             9  0.486926   0.0   0.0  0.021480   0.0  0.5574
# 3        1             6  0.499672   0.7   0.6  0.014320   0.0  0.0516
# 4        1            12  0.408704   0.0   0.0  0.028640   0.0  0.1027

# %%
train = pd.concat(data_stack).reset_index(drop = True)

# %%
data_stack[7].shape
# Out:
# (5488, 15)

# %%
X = train.iloc[:,:-1].values
y = train.iloc[:,-1].values

from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,shuffle = True, stratify = y) 
print("Test Len:",len(X_test)," ",len(y_test))
# Out:
# Test Len: 42443   42443

# %%
train
# Out:
#         review_len_x      Rn_x  Rp_x      Rs_x      Rc_x  Rd_x   Rsc_x  \
# 0                  5  0.544357  0.52  0.823333  0.006775   0.0  0.0000
# 1                  5  0.544357  0.52  0.823333  0.006775   0.0  0.0000
# 2                  5  0.544357  0.52  0.823333  0.006775   0.0  0.0000
# 3                  5  0.544357  0.52  0.823333  0.006775   0.0  0.0000
# 4                  5  0.544357  0.52  0.823333  0.006775   0.0  0.0000
# ...              ...       ...   ...       ...       ...   ...     ...
# 212207            10  0.418828  0.50  0.500000  0.023866   0.0 -0.1263
# 212208            10  0.418828  0.50  0.500000  0.023866   0.0 -0.1263
# 212209            10  0.418828  0.50  0.500000  0.023866   0.0 -0.1263
# 212210            10  0.418828  0.50  0.500000  0.023866   0.0 -0.1263
# 212211            10  0.418828  0.50  0.500000  0.023866   0.0 -0.1263
#
#         review_len_y      Rn_y      Rp_y      Rs_y      Rc_y  Rd_y   Rsc_y  \
# 0                  4  0.232859  0.300000  0.616667  0.005420   1.0  0.0000
# 1                 14  1.017469 -0.100000  0.400000  0.017615   1.0  0.0000
# 2                  5  0.319747  0.600000  0.800000  0.006775   1.0  0.4215
# 3                  2  0.545833  0.700000  0.600000  0.002710   0.0  0.4404
# 4                  2  0.545833  0.700000  0.600000  0.002710   0.0  0.4404
# ...              ...       ...       ...       ...       ...   ...     ...
# 212207            15  0.857801  0.700000  0.600000  0.035800   0.0  0.1531
# 212208             7  0.223776  0.316667  0.600000  0.016706   0.0  0.2382
# 212209            25  0.578632  0.233333  0.255556  0.059666   0.0  0.5927
# 212210            10  0.475974  0.500000  0.500000  0.023866   0.0  0.1779
# 212211            11  0.166375  0.690000  0.900000  0.026253   0.0  0.5709
#
#         target
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 212207       0
# 212208       0
# 212209       0
# 212210       0
# 212211       0
#
# [212212 rows x 15 columns]

# %% [markdown]
# # Spot Checking-
# + Linear Model
# + Non-Linear Model
# + Ensemble Model
#
# <hr>
#
# ## Linear Model: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train,y_train)
print("Training Accuracy\n", accuracy_score(y_train,classifier.predict(X_train)))
print("Test Accuracy\n", accuracy_score(y_test,classifier.predict(X_test)))

print('CLASSIFICATION REPORT')
print("Training\n", classification_report(y_train,classifier.predict(X_train)))
print("Test \n", classification_report(y_test,classifier.predict(X_test)))
# Out:
# C:\Users\manik\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Training Accuracy
#  0.8499431580559466
# Test Accuracy
#  0.8513771411068963
# CLASSIFICATION REPORT
# Training
#                precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85     84885
#            1       0.85      0.85      0.85     84884
#
#     accuracy                           0.85    169769
#    macro avg       0.85      0.85      0.85    169769
# weighted avg       0.85      0.85      0.85    169769
#
# Test
#                precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85     21221
#            1       0.85      0.85      0.85     21222
#
#     accuracy                           0.85     42443
#    macro avg       0.85      0.85      0.85     42443
# weighted avg       0.85      0.85      0.85     42443

# %% [markdown]
# ### Accuracy: 85%
# ### F1-score: 85%

# %% [markdown]
# ## Non-Linear Model: DecisionTree

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier

classifier = DecisionTreeClassifier()
classifier.fit(X_train,y_train)

print("Training Accuracy\n", accuracy_score(y_train,classifier.predict(X_train)))
print("Test Accuracy\n", accuracy_score(y_test,classifier.predict(X_test)))

print('CLASSIFICATION REPORT')
print("Training\n", classification_report(y_train,classifier.predict(X_train)))
print("Test \n", classification_report(y_test,classifier.predict(X_test)))
# Out:
# Training Accuracy
#  0.9967485229930082
# Test Accuracy
#  0.9862874914591334
# CLASSIFICATION REPORT
# Training
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     84885
#            1       1.00      0.99      1.00     84884
#
#     accuracy                           1.00    169769
#    macro avg       1.00      1.00      1.00    169769
# weighted avg       1.00      1.00      1.00    169769
#
# Test
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     21221
#            1       0.99      0.99      0.99     21222
#
#     accuracy                           0.99     42443
#    macro avg       0.99      0.99      0.99     42443
# weighted avg       0.99      0.99      0.99     42443

# %% [markdown]
# ## Ensemble Model: RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators=50, n_jobs = -1, oob_score = True,random_state=42)
classifier.fit(X_train,y_train)

print("Training Accuracy\n", accuracy_score(y_train,classifier.predict(X_train)))
print("Test Accuracy\n", accuracy_score(y_test,classifier.predict(X_test)))

print('CLASSIFICATION REPORT')
print("Training\n", classification_report(y_train,classifier.predict(X_train)))
print("Test \n", classification_report(y_test,classifier.predict(X_test)))

print("Test\nConfusion Matrix: \n", confusion_matrix(y_test, classifier.predict(X_test)))
# Out:
# Training Accuracy
#  0.9967485229930082
# Test Accuracy
#  0.989986570223594
# CLASSIFICATION REPORT
# Training
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84885
#            1       1.00      1.00      1.00     84884
#
#     accuracy                           1.00    169769
#    macro avg       1.00      1.00      1.00    169769
# weighted avg       1.00      1.00      1.00    169769
#
# Test
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     21221
#            1       0.99      0.99      0.99     21222
#
#     accuracy                           0.99     42443
#    macro avg       0.99      0.99      0.99     42443
# weighted avg       0.99      0.99      0.99     42443
#
# Test
# Confusion Matrix:
#  [[21013   208]
#  [  217 21005]]

# %%
## Score of the training dataset obtained using an out-of-bag estimate. This attribute exists only when oob_score is True.
classifier.oob_score_
# Out:
# 0.9892147565220977

# %%
feature_importances = pd.DataFrame(classifier.feature_importances_,
                                   index = train.iloc[:,:-1].columns,
                                    columns=['importance']).sort_values('importance',ascending=False)
feature_importances
# Out:
#               importance
# Rd_x            0.188866
# Rd_y            0.186374
# review_len_x    0.117197
# review_len_y    0.106647
# Rc_y            0.074865
# Rc_x            0.069707
# Rsc_y           0.043662
# Rn_y            0.042769
# Rn_x            0.038853
# Rsc_x           0.038356
# Rp_y            0.026215
# Rp_x            0.024970
# Rs_y            0.021406
# Rs_x            0.020111

# %%
dump(classifier, 'randomforest.joblib', compress = 2)
# Out:
# ['randomforest.joblib']

# %% [markdown]
# ## RandomForest Classifier Weights Saved.
# ### Accuracy: 0.98
# ### oob_score: 0.98
#
# + Note, if in your usecase data is too small to split to train-test-split then one can train model on entire data and measure out of bag score.

# %% [markdown]
# <hr>
#
# ## PART 2. Model Ranking Metric
#
# ### Accuracy of Ranking Methodology
# + After sorting the reviews by the review score, we wanted all reviews in Set 1 to be above all reviews of Set 0.
# + To test this hypothesis, we developed the following Ranking Metric
# + Let the number of 1s in our Dataset be x.
# ### `Ranking Accuracy on Single Product = Number of 1s found in first x positions / x`

# %%
classifier = load('randomforest.joblib')

# %%
classifier
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
#                        oob_score=True, random_state=42, verbose=0,
#                        warm_start=False)

# %%
product_list = df['product'].unique()
df['win']=0
df['lose']=0
df['review_score'] = 0.0
df.reset_index(inplace = True, drop = True)


def score_giver(C,D):
    E = pd.merge(C,D,how='outer',on='j')
    E.drop(columns=['j'],inplace = True)
    q= classifier.predict(E.values)
    return Counter(q),E

for product in product_list:
    data = df[df['product']==product]
    for indx in data.index:
        review = df.iloc[indx, 3:-3]
        review['j'] = 'jn'
        C = pd.DataFrame([review])
        D = data[data.index!=indx].iloc[:,3:-3]
        D['j'] = 'jn'
        score,E = score_giver(C,D)
        df.at[indx, 'win'] = 0 if score.get(1) is None else score.get(1)
        df.at[indx, 'lose'] = 0 if score.get(0) is None else score.get(0)
        df.at[indx, 'review_score'] = float(0 if score.get(1) is None else score.get(1)) / len(data) * 1.0

df = df.sort_values(by = ['product','review_score'], ascending = False)

r_accuracy =[]
for product in product_list:
    x = data_split[data_split.index == product][1][0]
    number_of_1_in_x = Counter(df[df['product']==product].iloc[:x, ]['label']).get(1)
    rank_accuracy = float(number_of_1_in_x*1.0 / x*1.0)
    print("Product: {} | Rank Accuracy: {}".format(product, rank_accuracy))
    r_accuracy.append(rank_accuracy)
print("Mean Rank Accuracy: {}".format(mean(r_accuracy)))
# Out:
# Product: shampoo | Rank Accuracy: 1.0
# Product: Supradyn | Rank Accuracy: 1.0
# Product: Shelcal | Rank Accuracy: 0.9516129032258065
# Product: SevenseascodLiverOil | Rank Accuracy: 1.0
# Product: Neurobion | Rank Accuracy: 0.9191176470588235
# Product: Evion | Rank Accuracy: 1.0
# Product: Becadexamin | Rank Accuracy: 1.0
# Product: Accucheck | Rank Accuracy: 0.9647058823529412
# Mean Rank Accuracy: 0.9794295540796965

# %%
len(df[df['product']==product].iloc[:x, ]['label'])
# Out:
# 85

# %%
df.iloc[:, [0,1,-1]].to_csv('data/train_ranked_output.csv',index = False)

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
t = pd.read_csv('data/test.csv')
